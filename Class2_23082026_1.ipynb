# %% [markdown]
# <a href="https://colab.research.google.com/github/maryooma05/100_plus_Python_Projects_Challenge/blob/main/Class2_23082026_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print("Welcome to Machine learning")
# Out:
# Welcome to Machine learning

# %%
name = "Mariam"
print("Hello", name)
# Out:
# Hello Mariam

# %%
name = Mariam
age = 25
height=1.65
is_student = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6410/830881991.py in <cell line: 0>()
# ----> 1 name = Mariam
#       2 age = 25
#       3 height=1.65
#       4 is_student = true
#
# NameError: name 'Mariam' is not defined

# %%
title = "This is a great book"
print(title)
print(title.lower())
print(title.upper())
len(title)
"great" in title
# Out:
# This is a great book
# this is a great book
# THIS IS A GREAT BOOK
# True

# %%
ratings = [5,4,3,5,2]
print(ratings)
print(ratings[0])
# Out:
# [5, 4, 3, 5, 2]
# 5

# %%
rating = 5
if rating >= 4:
  print("Positive review")
else:
  print("Not a positive review")
# Out:
# Positive review

# %%
ratings = [5,4,3,5,2]
for rating in ratings:
  print(rating)
# Out:
# 5
# 4
# 3
# 5
# 2

# %%
def greet(name):
    print("Hello", name)
greet("Mariam")
# Out:
# Hello Mariam

# %%
import pandas as pd
data = {
    "review": ["Great book", "Not useful", "Excellent"],
    "rating": [5,2,5]

}

df = pd.DataFrame(data)
df.head()
#df.shape()
# Out:
#        review  rating
# 0  Great book       5
# 1  Not useful       2
# 2   Excellent       5

# %%
import pandas as pd
data = {
    "review": ["Great book", "Not useful", "Excellent"],
    "rating": [5,2,5]

}

df = pd.DataFrame(data)
df.shape
# Out:
# (3, 2)
